# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroSaltos/APIfinance-python/blob/main/2_Funciones_dentro_de_otras_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

N=100
x=np.linspace(-10,10,num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

y=g(x)
f_o_g=f(g(x))

plt.plot(x,f_o_g)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

y = g(x)

f_o_g = f(g(x))

plt.plot(x,f_o_g)
